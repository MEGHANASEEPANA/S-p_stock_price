# %%
#yahoo finance
# !pip install yfinance

# %%
#import yfinance 
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
#s&p global 500 stock prices 
sp_gspc = sp500.history("max")

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %%
#find information about the company and other details
sp_gspc.info
# Out:
# <bound method DataFrame.info of                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# ...

# %%
#find index of the historical data. Here date time showed as the index
sp_gspc.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2024-04-02 00:00:00-04:00', '2024-04-03 00:00:00-04:00',
#                '2024-04-04 00:00:00-04:00', '2024-04-05 00:00:00-04:00',
#                '2024-04-08 00:00:00-04:00', '2024-04-09 00:00:00-04:00',
#                '2024-04-10 00:00:00-04:00', '2024-04-11 00:00:00-04:00',
#                '2024-04-12 00:00:00-04:00', '2024-04-15 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24187, freq=None)

# %% [markdown]
# #Cleaning and visualising the stock market data

# %%
sp_gspc.plot(y= "Close",use_index = True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
del sp_gspc["Dividends"]
del sp_gspc["Stock Splits"]

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %% [markdown]
# #Setting up Target for machine learning

# %%
sp_gspc["Tomorrow"] = sp_gspc["Close"].shift(-1)

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %%
sp_gspc["Target"] = (sp_gspc["Tomorrow"] > sp_gspc["Close"]).astype(int)

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %%
sp_gspc = sp_gspc.loc["1990-01-01":].copy()

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %% [markdown]
# #Training an Initial Machine learning model

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=42)

train = sp_gspc.iloc[:-100]

test = sp_gspc.iloc[-100:]

predictors = ["Close","Volume","Open","High","Low"]

model.fit(train[predictors],train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=42)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index = test.index)

# %%
precision_score(test["Target"],preds)
# Out:
# 0.5833333333333334

# %%
combined = pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
#building a backtesting system

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds,index=test.index,name="Predictions")
    combined = pd.concat([test["Target"],preds],axis=1)
    return combined

# %%
def backtest(data,model,predictors,start=2500,step=250):
    all_predictions = []
    
    for i in range(start,data.shape[0],step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test,predictors,model)
        all_predictions.append(predictions)
        
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp_gspc,model,predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0    3422
# 1    2715
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5307550644567219

# %%
predictions["Target"].value_counts()/predictions.shape[0]
# Out:
# 1    0.534463
# 0    0.465537
# Name: Target, dtype: float64

# %%
#Other methods to predict

# %%
horizons = [2,5,60,250,1000]

new_predictors = []

for horizon in horizons:
    rolling_averages = sp_gspc.rolling(horizon).mean()
    ratio_column = f"Close_Ratio_{horizon}"
    sp_gspc[ratio_column] = sp_gspc["Close"]/rolling_averages["Close"]
    
    trend_column = f"Trend_{horizon}"
    sp_gspc[trend_column] = sp_gspc.shift(1).rolling(horizon).sum()["Target"]
    
    new_predictors += [ratio_column,trend_column]

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
# 2024-04-15 00:00:00-04:00  5149.669922  5168.430176  5052.470215  5061.819824
#
# ...

# %%
sp_gspc = sp_gspc.dropna()

# %%
sp_gspc
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2024-04-08 00:00:00-04:00  5211.370117  5219.569824  5197.350098  5202.390137
# 2024-04-09 00:00:00-04:00  5217.029785  5224.810059  5160.779785  5209.910156
# 2024-04-10 00:00:00-04:00  5167.879883  5178.430176  5138.700195  5160.640137
# 2024-04-11 00:00:00-04:00  5172.950195  5211.779785  5138.770020  5199.060059
# 2024-04-12 00:00:00-04:00  5171.509766  5175.029785  5107.939941  5123.410156
#
# ...

# %%
#improving the model

# %%
model = RandomForestClassifier(n_estimators=200,min_samples_split=50,random_state=42)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds,index = test.index,name= "Predictions")
    combined = pd.concat([test["Target"],preds],axis = 1)
    return combined

# %%
predictions = backtest(sp_gspc,model,new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# 0.0    4343
# 1.0     793
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.575031525851198
